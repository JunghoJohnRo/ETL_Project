# %% [markdown]
# # Bad Boys of the National Football League
# By Amber Billings and John Ro
#
# #### Data Sources
# We initially found an NFL arrests API and found the source from which the API was pulling data, USA Today (https://www.usatoday.com/sports/nfl/arrests/). To connect arrests with any consequences players would have faced after their arrests within the NFL, we pulled a table of NFL suspensions from Wikipedia (https://en.wikipedia.org/wiki/List_of_suspensions_in_the_National_Football_League). The NFL arrests data contained only the team abbreviations and the suspensions table contained only the full team name. We scraped a list of NFL team names and abbreviations from Quizlet (https://quizlet.com/80005100/nfl-teams-by-abbreviation-flash-cards/).

# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine
from splinter import Browser
from bs4 import BeautifulSoup

# %% [markdown]
# ### Scraping data on NFL arrests

# %%
url = 'https://www.usatoday.com/sports/nfl/arrests/'

# %%
tables = pd.read_html(url)
tables
# Out:
# [           Date Team                  Name POS         Case  \
#  0    2019-04-26  HOU          Ryan Griffin  TE     Arrested
#  1    2019-04-13  PHI           Jalen Mills  CB     Arrested
#  2    2019-04-11  JAC     Leonard Fournette  RB     Arrested
#  3    2019-04-04  CIN           Mark Walton  RB  Surrendered
#  4    2019-03-01  BAL          Alex Collins  RB     Arrested
#  5    2019-02-15  CIN           Mark Walton  RB     Arrested
#  6    2019-01-26  DET          Trevor Bates  LB     Arrested
#  7    2019-01-26   KC    De''Anthony Thomas  WR     Arrested
#  8    2019-01-23   NO         P.J. Williams  CB     Arrested
#  9    2019-01-16  CIN           Mark Walton  RB      Charged
#  10   2018-12-18  WAS      Montae Nicholson   S     Arrested
#  11   2018-11-24   SF         Reuben Foster  LB     Arrested
#  12   2018-10-30  NYG         Kyle Lauletta  QB     Arrested
#  13   2018-10-22  DEN            Chad Kelly  QB     Arrested
#  14   2018-09-16  LAR           Aaron Neary  OC     Arrested
#  15   2018-08-31  DAL          Rico Gathers  TE     Arrested
#  16   2018-08-29  CLE      Mychal Kendricks  LB      Charged
#  17   2018-08-28  MIN          Cayleb Jones  WR     Arrested
#  18   2018-08-05  CLE      Antonio Callaway  WR        Cited
#  19   2018-07-14  CAR         Vernon Butler  DT        Cited
#  20   2018-07-14  ARI     Ricky Seals-Jones  TE     Arrested
#  21   2018-06-15  DAL         Marquez White  CB     Arrested
#  22   2018-06-09  CIN        Logan Woodside  QB     Arrested
#  23   2018-06-03  IND          Chris McCain  DE      Charged
#  24   2018-06-02  NYJ         Chris Herndon  TE     Arrested
#  25   2018-05-19  MIN     Antwione Williams  LB     Arrested
#  26   2018-05-19  DAL     Terrance Williams  WR     Arrested
#  27   2018-04-15   GB          Trevor Davis  WR     Arrested
#  28   2018-04-15  PHI          Daryl Worley  CB     Arrested
#  29   2018-03-23  SEA       Michael Bennett  DE     Indicted
#  ..          ...  ...                   ...  ..          ...
#  903  2000-08-13   NO          Darren Perry   S     Arrested
#  904  2000-08-09  DEN       Bill Romanowski  LB     Indicted
#  905  2000-08-07   KC           Andre Rison  WR        Cited
#  906  2000-07-28   TB      Darnell McDonald  WR     Arrested
#  907  2000-07-20  CIN          Darnay Scott  WR     Arrested
#  908  2000-07-18  MIA       Patrick Surtain  CB     Arrested
#  909  2000-07-07   SD       Leonardo Carson  DT      Charged
#  910  2000-06-21  OAK  Sebastian Janikowski   K     Arrested
#  911  2000-06-11  CHI        Bryan Robinson  DE      Charged
#  912  2000-05-24  OAK       Charles Woodson  CB     Arrested
#  913  2000-05-20  BAL       Chris McAlister  CB      Charged
#  914  2000-05-19   GB          Marco Rivera  OG     Arrested
#  915  2000-05-13  WAS          Mike Sellers  FB     Arrested
#  916  2000-04-17  DAL           Tony Hutson  OT     Arrested
#  917  2000-04-10   GB           Mark Chmura  TE     Arrested
#  918  2000-04-06  CIN           Steve Foley  LB     Arrested
#  919  2000-04-01   GB        De'Mond Parker  RB     Arrested
#  920  2000-03-31  MIN           Chris Walsh  WR     Arrested
#  921  2000-03-23  DAL          Solomon Page  OT     Arrested
#  922  2000-03-14  ARI           Mario Bates  RB     Arrested
#  923  2000-02-22   KC      Tamarick Vanover  WR      Charged
#  924  2000-02-21   NO        Ricky Williams  RB     Arrested
#  925  2000-02-19  TEN           Benji Olson  OG     Arrested
#  926  2000-02-16   KC           Andre Rison  WR     Arrested
#  927  2000-02-06  NYJ         Wayne Chrebet  WR     Arrested
#  928  2000-02-06  IND           Keith Elias  RB     Arrested
#  929  2000-02-05  CIN           Steve Foley  LB     Arrested
#  930  2000-02-03  CAR             Fred Lane  RB     Arrested
#  931  2000-01-31  BAL             Ray Lewis  LB      Charged
#  932  2000-01-24  DEN             Rod Smith  WR     Arrested
#
#                     Category  \
#  0       Public intoxication
#  1        Disorderly conduct
#  2                   License
#  3                Drugs, gun
#  4                Drugs, gun
#  5                   Battery
#  6                   Assault
#  7                     Drugs
#  8                       DUI
#  9                     Drugs
#  10                  Assault
#  11        Domestic violence
#  12           Eluding police
#  13              Trespassing
#  14                      DUI
#  15                    Drugs
#  16          Insider trading
#  17         Domestic assault
#  18                    Drugs
#  19                  Assault
#  20                  Assault
#  21                  Assault
#  22                      DUI
#  23                  Battery
#  24                      DUI
#  25                      DUI
#  26      Public intoxication
#  27              Bomb threat
#  28                      DUI
#  29        Injury to elderly
#  ..                      ...
#  903                     DUI
#  904                   Drugs
#  905       False information
#  906       Burglary, battery
#  907                   Theft
#  908                     DUI
#  909                 Assault
#  910                   Drugs
#  911                 Battery
#  912                     DUI
#  913                   Drugs
#  914                     DUI
#  915                     DUI
#  916  Failure to appear, gun
#  917          Sexual assault
#  918                     Gun
#  919                   Drugs
#  920                     DUI
#  921      Disorderly conduct
#  922       Domestic violence
#  923                   Theft
#  924       Failure to appear
#  925                     DUI
#  926                   Theft
#  927      Disorderly conduct
#  928      Disorderly conduct
#  929       Domestic violence
#  930              Drugs, gun
#  931                  Murder
#  932       Domestic violence
#
#                                             Description  \
#  0    Accused of punching out window of hotel in Nas...
#  1    Accused of getting into an altercation with NB...
#  2    Pulled over for speeding in Jacksonville, accu...
#  3    Accused of carrying a concealed weapon, mariju...
#  4    Police responded to report of a car crash and ...
#  5    Accused of misdemeanor and getting into a scuf...
#  6    Accused of punching a police officer after not...
#  7    Suspected of possessing marijuana and drug par...
#  8    Pulled over for speeding, accused of driving d...
#  9    Pulled over for not wearing a seat belt, accus...
#  10   Suspected of assault and public drunkenness af...
#  11   Accused of pushing and slapping a woman in Tam...
#  12   Accused of resisting arrest, eluding police an...
#  13   Charged with first-degree criminal trespassing...
#  14   Suspected of driving drunk in Simi Valley, Cal...
#  15   Suspected of marijuana possession in Frisco, T...
#  16   Accused of taking advantage of non-public tips...
#  17   Suspected of misdemeanor domestic assault, int...
#  18   Pulled over for traffic violation in Strongvil...
#  19   Accused of pushing and throwing drink in the f...
#  20   Accused of pushing hotel staffer in effort to ...
#  21   Accused of aggravated assault with a deadly we...
#  22   Pulled over in Kentucky for speeding, suspecte...
#  23   Accused of spitting on a woman and grabbing he...
#  24   Suspected of driving while intoxicated after c...
#  25   Pulled over for speeding in Minnesota, suspect...
#  26   Suspected of public intoxication after police ...
#  27   Accused of talking about explosives when check...
#  28   Accused of resisting arrest after being found ...
#  29   Accused of pushing his way past a 66-year-old ...
#  ..                                                 ...
#  903  Accused of drunk driving, hit-and-run and rear...
#  904  Accused of illegaly obtaining prescription die...
#  905  Accused of lying to police about his name afte...
#  906  Accused of aggravated battery with great bodil...
#  907  Accused of writing a back check for more than ...
#  908  Pulled over in Miami for speeding, accused of ...
#  909  Accused of third-degree assault, one of string...
#  910  Accused of possession of a controlled substanc...
#  911  Accused of spitting on a woman's face at a bar...
#  912  Accused of drunk driving and driving with a su...
#  913  Accused of marijuana possession after authorit...
#  914  Pulled over for speeding at 95 mph in Brown Co...
#  915  Pulled over in Arlington, Va., after police sa...
#  916  Pulled over for speeding in Texas, accused of ...
#  917  Accused of encouraging teenagers to drink, sex...
#  918  Accused of firing gun into the air several tim...
#  919  Accused of marijuana possession near Chicago a...
#  920  Pulled over near his home in Scottsdale, Ariz....
#  921  Accused of throwing punches and obstructing po...
#  922  Accused of slapping his girlfriend in the face...
#  923  Accused of assisting in the sale of a stolen v...
#  924  Pulled over in Austin, Texas, accused of impro...
#  925  Pulled over at a shopping center in Hopkinsvil...
#  926  Accused of renting but not returning a $1,100 ...
#  927  Accused of disorderly conduct in altercation o...
#  928  Accused of resisting arrest and disorderly con...
#  929  Accused of kicking in the door of his son's mo...
#  930  Police pulled him over in Jackson, Tenn., for ...
#  931  Accused of murder in the stabbing deaths of tw...
#  932  Accused of choking, beating and shoving his co...
#
#                                                 Outcome
#  0                             Resolution undetermined.
#  1                             Resolution undetermined.
#  2                             Resolution undetermined.
#  3    Resolution undetermined. Team released him lat...
#  4    Resolution undetermined. Team released him sam...
#  5                             Resolution undetermined.
#  6                             Resolution undetermined.
#  7                             Resolution undetermined.
#  8                             Resolution undetermined.
#  9                             Resolution undetermined.
#  10                            Resolution undetermined.
#  11   Dropped by prosecutors. Released by team the m...
#  12                            Resolution undetermined.
#  13   Pleaded guilty to misdemeanor, one year probat...
#  14                            Resolution undetermined.
#  15   Deferred prosecution agreement, $99 fine, cour...
#  16                 Pleaded guilty. Released by Browns.
#  17                            Resolution undetermined.
#  18   Drug charge dropped. Paid $911 related to lice...
#  19                            Resolution undetermined.
#  20   Pleaded guilty to misdemeanor, diversion progr...
#  21                            Resolution undetermined.
#  22                            Resolution undetermined.
#  23                            Resolution undetermined.
#  24                            Resolution undetermined.
#  25   Pleaded guilty to misdemeanor, one year probat...
#  26   Diversion program in alcohol awareness, paid r...
#  27                             Dropped by prosecutors.
#  28   Pleaded guilty to three charges, 72 hours in j...
#  29                             Dropped by prosecutors.
#  ..                                                 ...
#  903                           Resolution undetermined.
#  904                                 Acquitted by jury.
#  905  Guilty, fined $219.50. Team cut him a few days...
#  906  Pleaded out, two years probation, 150 hours of...
#  907  Charge dropped, but he spent a night in jail a...
#  908  Pleaded no contest to reckless driving, 50 hou...
#  909                                    Charge dropped.
#  910                                 Acquitted by jury.
#  911                           Resolution undetermined.
#  912  Pleaded guilty to driving while impaired, 60 h...
#  913               Charge dropped for lack of evidence.
#  914  Pleaded no contest, $455 speeding ticket, $675...
#  915  Convicted of DUI, 18-month suspended jail sent...
#  916                           Resolution undetermined.
#  917                                 Acquitted by jury.
#  918               Charge dropped for lack of evidence.
#  919  Diversion program. Charge dropped in exchange ...
#  920  Pleaded guilty to drunk driving, $1,277 fine, ...
#  921  Pleaded no contest to reduced charged, $200 fine.
#  922  Pleaded guilty, $364 fine, two years of probat...
#  923  Pleaded guilty, $10,000 fine, $6,241 to the in...
#  924                     Guilty, pleaded $429 in fines.
#  925  Pleaded to a reduced charge of failing to oper...
#  926  Pleaded no contest, sentenced to one year of p...
#  927  Pleaded guilty to nuisance violation, fined $230.
#  928  Pleaded guilty to nuisance violation, fined $230.
#  929  Charge dropped after woman declined to cooperate.
#  930  Indicted but shot and killed by his wife in Ju...
#  931  Pleaded guilty to obstruction of justice, one ...
#  932  Pleaded guilty to misdemeanor count of verbal ...
#
#  [933 rows x 8 columns]]

# %%
arrests_df = tables[0]
arrests_df.columns = ['date', 'team', 'name', 'position', 'case', 'category', 'description', 'outcome']
arrests_df.head(10)
# Out:
#          date team                name position         case  \
# 0  2019-04-26  HOU        Ryan Griffin       TE     Arrested
# 1  2019-04-13  PHI         Jalen Mills       CB     Arrested
# 2  2019-04-11  JAC   Leonard Fournette       RB     Arrested
# 3  2019-04-04  CIN         Mark Walton       RB  Surrendered
# 4  2019-03-01  BAL        Alex Collins       RB     Arrested
# 5  2019-02-15  CIN         Mark Walton       RB     Arrested
# 6  2019-01-26  DET        Trevor Bates       LB     Arrested
# 7  2019-01-26   KC  De''Anthony Thomas       WR     Arrested
# 8  2019-01-23   NO       P.J. Williams       CB     Arrested
# 9  2019-01-16  CIN         Mark Walton       RB      Charged
#
#               category                                        description  \
# 0  Public intoxication  Accused of punching out window of hotel in Nas...
# 1   Disorderly conduct  Accused of getting into an altercation with NB...
# 2              License  Pulled over for speeding in Jacksonville, accu...
# 3           Drugs, gun  Accused of carrying a concealed weapon, mariju...
# 4           Drugs, gun  Police responded to report of a car crash and ...
# 5              Battery  Accused of misdemeanor and getting into a scuf...
# 6              Assault  Accused of punching a police officer after not...
# 7                Drugs  Suspected of possessing marijuana and drug par...
# 8                  DUI  Pulled over for speeding, accused of driving d...
# 9                Drugs  Pulled over for not wearing a seat belt, accus...
#
#                                              outcome
# 0                           Resolution undetermined.
# 1                           Resolution undetermined.
# 2                           Resolution undetermined.
# 3  Resolution undetermined. Team released him lat...
# 4  Resolution undetermined. Team released him sam...
# 5                           Resolution undetermined.
# 6                           Resolution undetermined.
# 7                           Resolution undetermined.
# 8                           Resolution undetermined.
# 9                           Resolution undetermined.

# %% [markdown]
# ### Cleaning arrests data
#
# To transform this data, we first looked through the list to find any errors in names and fixed those. We renamed the column 'case' because that is a reserved word in MySQL. We also sorted by date in ascending order.

# %%
arrests_df.loc[arrests_df['name'] == "De''Anthony Thomas", 'name'] = "De'Anthony Thomas"

# %%
arrests_df = arrests_df.sort_values(by='date')
arrests_df = arrests_df.reset_index(drop=True)

# %%
arrests_df = arrests_df.rename(columns={'case': 'action', 'team': 'abbreviation'})
arrests_df.head(10)
# Out:
#          date abbreviation              name position    action  \
# 0  2000-01-24          DEN         Rod Smith       WR  Arrested
# 1  2000-01-31          BAL         Ray Lewis       LB   Charged
# 2  2000-02-03          CAR         Fred Lane       RB  Arrested
# 3  2000-02-05          CIN       Steve Foley       LB  Arrested
# 4  2000-02-06          NYJ     Wayne Chrebet       WR  Arrested
# 5  2000-02-06          IND       Keith Elias       RB  Arrested
# 6  2000-02-16           KC       Andre Rison       WR  Arrested
# 7  2000-02-19          TEN       Benji Olson       OG  Arrested
# 8  2000-02-21           NO    Ricky Williams       RB  Arrested
# 9  2000-02-22           KC  Tamarick Vanover       WR   Charged
#
#              category                                        description  \
# 0   Domestic violence  Accused of choking, beating and shoving his co...
# 1              Murder  Accused of murder in the stabbing deaths of tw...
# 2          Drugs, gun  Police pulled him over in Jackson, Tenn., for ...
# 3   Domestic violence  Accused of kicking in the door of his son's mo...
# 4  Disorderly conduct  Accused of disorderly conduct in altercation o...
# 5  Disorderly conduct  Accused of resisting arrest and disorderly con...
# 6               Theft  Accused of renting but not returning a $1,100 ...
# 7                 DUI  Pulled over at a shopping center in Hopkinsvil...
# 8   Failure to appear  Pulled over in Austin, Texas, accused of impro...
# 9               Theft  Accused of assisting in the sale of a stolen v...
#
#                                              outcome
# 0  Pleaded guilty to misdemeanor count of verbal ...
# 1  Pleaded guilty to obstruction of justice, one ...
# 2  Indicted but shot and killed by his wife in Ju...
# 3  Charge dropped after woman declined to cooperate.
# 4  Pleaded guilty to nuisance violation, fined $230.
# 5  Pleaded guilty to nuisance violation, fined $230.
# 6  Pleaded no contest, sentenced to one year of p...
# 7  Pleaded to a reduced charge of failing to oper...
# 8                     Guilty, pleaded $429 in fines.
# 9  Pleaded guilty, $10,000 fine, $6,241 to the in...

# %% [markdown]
# ### Scraping NFL team abbreviations

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://quizlet.com/80005100/nfl-teams-by-abbreviation-flash-cards/"
browser.visit(url)

# %%
abbr_list = []
for i in range(32):
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    team = soup.find_all(class_='SetPageTerm-wordText')[i]
    nfl_team = team.find('span').text
    
    abbreviation = soup.find_all(class_='SetPageTerm-definitionText')[i]
    nfl_abbr = abbreviation.find('span').text
    
    abbr_list.append({"team": nfl_team, 
                      "abbreviation": nfl_abbr})

# %%
abbr_list
# Out:
# [{'team': 'New York Jets', 'abbreviation': 'NYJ'},
#  {'team': 'New York Giants', 'abbreviation': 'NYG'},
#  {'team': 'Arizona Cardinals', 'abbreviation': 'ARI'},
#  {'team': 'Baltimore Ravens', 'abbreviation': 'BAL'},
#  {'team': 'Seattle Seahawks', 'abbreviation': 'SEA'},
#  {'team': 'Pittsburgh Steelers', 'abbreviation': 'PIT'},
#  {'team': 'New England Patriots', 'abbreviation': 'NE'},
#  {'team': 'St. Louis Rams', 'abbreviation': 'STL'},
#  {'team': 'Oakland Raiders', 'abbreviation': 'OAK'},
#  {'team': 'Houston Texans', 'abbreviation': 'HOU'},
#  {'team': 'Dallas Cowboys', 'abbreviation': 'DAL'},
#  {'team': 'Jacksonville Jaguars', 'abbreviation': 'JAX'},
#  {'team': 'San Diego Chargers', 'abbreviation': 'SD'},
#  {'team': 'Denver Broncos', 'abbreviation': 'DEN'},
#  {'team': 'Indianapolis Colts', 'abbreviation': 'IND'},
#  {'team': 'Tennessee Titans', 'abbreviation': 'TEN'},
#  {'team': 'Tampa Bay Buccaneers', 'abbreviation': 'TB'},
#  {'team': 'Carolina Panthers', 'abbreviation': 'CAR'},
#  {'team': 'Buffalo Bills', 'abbreviation': 'BUF'},
#  {'team': 'Green Bay Packers', 'abbreviation': 'GB'},
#  {'team': 'Chicago Bears', 'abbreviation': 'CHI'},
#  {'team': 'Kansas City Chiefs', 'abbreviation': 'KC'},
#  {'team': 'Miami Dolphins', 'abbreviation': 'MIA'},
#  {'team': 'Cincinnati Bengals', 'abbreviation': 'CIN'},
#  {'team': 'Cleveland Browns', 'abbreviation': 'CLE'},
#  {'team': 'Detroit Lions', 'abbreviation': 'DET'},
#  {'team': 'New Orleans Saints', 'abbreviation': 'NO'},
#  {'team': 'San Francisco 49ers', 'abbreviation': 'SF'},
#  {'team': 'Minnesota Vikings', 'abbreviation': 'MIN'},
#  {'team': 'Philadelphia Eagles', 'abbreviation': 'PHI'},
#  {'team': 'Washington Redskins', 'abbreviation': 'WAS'},
#  {'team': 'Atlanta Falcons', 'abbreviation': 'ATL'}]

# %%
nfl_abbrevs = pd.DataFrame.from_dict(abbr_list)
nfl_abbrevs.head()
# Out:
#   abbreviation               team
# 0          NYJ      New York Jets
# 1          NYG    New York Giants
# 2          ARI  Arizona Cardinals
# 3          BAL   Baltimore Ravens
# 4          SEA   Seattle Seahawks

# %% [markdown]
# ### Merging arrests and abbreviations tables
#
# We merged the arrests table with the team abbreviations so the data would match what is in the suspensions table. Then we reordered the columns to be consistent with the original arrests table.

# %%
arrests_join = pd.merge(arrests_df, nfl_abbrevs, how='outer', on='abbreviation')
arrests_join.head()
# Out:
#          date abbreviation             name position    action  \
# 0  2000-01-24          DEN        Rod Smith       WR  Arrested
# 1  2000-08-09          DEN  Bill Romanowski       LB  Indicted
# 2  2000-10-28          DEN     Brian Griese       QB  Arrested
# 3  2001-03-02          DEN  Dwayne Carswell       TE  Arrested
# 4  2001-09-02          DEN   Eddie Kennison       WR  Arrested
#
#              category                                        description  \
# 0   Domestic violence  Accused of choking, beating and shoving his co...
# 1               Drugs  Accused of illegaly obtaining prescription die...
# 2                 DUI  Pulled over for speeding near Denver, accused ...
# 3   Domestic violence  Accused of pulling a woman's hair and bruising...
# 4  Disorderly conduct  Accused of inciting a riot at Louisiana nightc...
#
#                                              outcome            team
# 0  Pleaded guilty to misdemeanor count of verbal ...  Denver Broncos
# 1                                 Acquitted by jury.  Denver Broncos
# 2             Pleaded guilty, one year of probation.  Denver Broncos
# 3              Diversion program, community service.  Denver Broncos
# 4                                   Charges dropped.  Denver Broncos

# %%
nfl_arrests = arrests_join.drop(columns=['abbreviation'])
nfl_arrests = nfl_arrests[['date', 'name', 'position', 'team', 'action', 'category', 'description', 'outcome']]
nfl_arrests.head()
# Out:
#          date             name position            team    action  \
# 0  2000-01-24        Rod Smith       WR  Denver Broncos  Arrested
# 1  2000-08-09  Bill Romanowski       LB  Denver Broncos  Indicted
# 2  2000-10-28     Brian Griese       QB  Denver Broncos  Arrested
# 3  2001-03-02  Dwayne Carswell       TE  Denver Broncos  Arrested
# 4  2001-09-02   Eddie Kennison       WR  Denver Broncos  Arrested
#
#              category                                        description  \
# 0   Domestic violence  Accused of choking, beating and shoving his co...
# 1               Drugs  Accused of illegaly obtaining prescription die...
# 2                 DUI  Pulled over for speeding near Denver, accused ...
# 3   Domestic violence  Accused of pulling a woman's hair and bruising...
# 4  Disorderly conduct  Accused of inciting a riot at Louisiana nightc...
#
#                                              outcome
# 0  Pleaded guilty to misdemeanor count of verbal ...
# 1                                 Acquitted by jury.
# 2             Pleaded guilty, one year of probation.
# 3              Diversion program, community service.
# 4                                   Charges dropped.

# %% [markdown]
# ### Uploading CSV file of NFL suspensions
# Pulled from Wikipedia, preliminary transformation in Google Sheets.
#
# To transform this data, we renamed the columns and ordered by date in ascending order.

# %%
csv_file = "resources/suspensions.csv"
nfl_bad_boys_df = pd.read_csv(csv_file)
nfl_bad_boys_df.head()
# Out:
#   Date suspended Suspension length             Name Position  \
# 0     2019-03-01        Indefinite     David Irving       DL
# 1     2019-02-26        Indefinite    Randy Gregory       DE
# 2     2018-12-20        Indefinite      Josh Gordon       WR
# 3     2018-12-14        Indefinite  Martavis Bryant       WR
# 4     2018-12-07           4 games       Darron Lee       LB
#
#   Team at the time of suspension                            Reason
# 0                 Dallas Cowboys  Violating the substance policies
# 1                 Dallas Cowboys  Violating the substance policies
# 2           New England Patriots  Violating the substance policies
# 3                Oakland Raiders  Violating the substance policies
# 4                  New York Jets  Violating the substance policies

# %%
nfl_bad_boys_df = nfl_bad_boys_df.rename(columns={'Date suspended': 'date', 'Suspension length': 'length',
                                                  'Name': 'name', 'Position': 'position', 
                                                  'Team at the time of suspension': 'team', 'Reason': 'description'})
nfl_bad_boys_df = nfl_bad_boys_df.sort_values(by='date')
nfl_bad_boys_df = nfl_bad_boys_df.reset_index(drop=True)
nfl_bad_boys_df.head()
# Out:
#          date                     length            name position  \
# 0  1925-12-17  Life (reinstated in 1926)        Art Folz       QB
# 1  1947-04-03                       Life     Merle Hapes       RB
# 2  1947-04-03                       Life  Frank Filchock       QB
# 3  1947-11-22                     1 game   Jack Matheson       OE
# 4  1963-04-17         Entire 1963 season     Alex Karras       DT
#
#                 team                                        description
# 0  Chicago Cardinals  Involvement in the 1925 Chicago Cardinals–Milw...
# 1    New York Giants              Fixing the 1946 NFL Championship Game
# 2    New York Giants              Fixing the 1946 NFL Championship Game
# 3      Chicago Bears                  Conduct detrimental to the league
# 4      Detroit Lions                               Betting on NFL games

# %% [markdown]
# ### Relational Database
#
# We chose SQL because there are strong consistency in columns from both tables like date, name, position and team. Right now, neither table has a primary key, but if this database was built out more in the future, there could be a players table and a teams table with specific IDs that link between tables.

# %% [markdown]
# ### Create database connection

# %%
connection_string = "root:armistice9@127.0.0.1/nfl_bad_boys"
engine = create_engine(f'mysql+pymysql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['arrests', 'suspensions']

# %% [markdown]
# ### Loading DataFrames into database

# %%
nfl_arrests.to_sql(name='arrests', con=engine, if_exists='append', index=False)

# %%
nfl_bad_boys_df.to_sql(name='suspensions', con=engine, if_exists='append', index=False)
